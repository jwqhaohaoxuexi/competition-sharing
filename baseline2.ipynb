# %%
import datetime
from sklearn.feature_selection import chi2, SelectPercentile
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from scipy import sparse
import lightgbm as lgb
import warnings
import time
import pandas as pd
import numpy as np
import os
import gc
from sklearn.model_selection import train_test_split
path = './data'

warnings.filterwarnings("ignore")

train = pd.read_table(path + '/round1_iflyad_train.txt')
test = pd.read_table(path + '/round1_iflyad_test_feature.txt')
data = pd.concat([train, test], axis=0, ignore_index=True)

data = data.fillna(-1)

data['day'] = data['time'].apply(lambda x: int(time.strftime("%d", time.localtime(x))))
data['hour'] = data['time'].apply(lambda x: int(time.strftime("%H", time.localtime(x))))
data['label'] = data.click.astype(int)
data['area'] = data['creative_height'] * data['creative_width']



bool_feature = ['creative_is_jump', 'creative_is_download', 'creative_is_js', 'creative_is_voicead',
                'creative_has_deeplink', 'app_paid']
for i in bool_feature:
    data[i] = data[i].astype(int)

data['advert_industry_inner_1'] = data['advert_industry_inner'].apply(lambda x: x.split('_')[0])

data['period'] = data['day']
data['period'][data['period']<27] = data['period'][data['period']<27] + 31


for feat_1 in ['advert_id','advert_industry_inner_1', 'advert_industry_inner','advert_name','campaign_id', 'creative_height',
               'creative_tp_dnf', 'creative_width', 'province', 'f_channel','area']:
    gc.collect()
    res=pd.DataFrame()
    temp=data[[feat_1,'period','click']]
    for period in range(27,35):
        if period == 27:
            count=temp.groupby([feat_1]).apply(lambda x: x['click'][(x['period']<=period).values].count()).reset_index(name=feat_1+'_all')
            count1=temp.groupby([feat_1]).apply(lambda x: x['click'][(x['period']<=period).values].sum()).reset_index(name=feat_1+'_1')
        else: 
            count=temp.groupby([feat_1]).apply(lambda x: x['click'][(x['period']<period).values].count()).reset_index(name=feat_1+'_all')
            count1=temp.groupby([feat_1]).apply(lambda x: x['click'][(x['period']<period).values].sum()).reset_index(name=feat_1+'_1')
        count[feat_1+'_1']=count1[feat_1+'_1']
        count.fillna(value=0, inplace=True)
        count[feat_1+'_rate'] = round(count[feat_1+'_1'] / count[feat_1+'_all'], 5)
        count['period']=period
        count.drop([feat_1+'_all', feat_1+'_1'],axis=1,inplace=True)
        count.fillna(value=0, inplace=True)
        res=res.append(count,ignore_index=True)
    print(feat_1,' over')
    data = pd.merge(data,res, how='left', on=[feat_1,'period'])


ad_cate_feature = ['adid', 'advert_id', 'orderid', 'advert_industry_inner_1', 'advert_industry_inner', 'advert_name',
                   'campaign_id', 'creative_id', 'creative_type', 'creative_tp_dnf', 'creative_has_deeplink',
                   'creative_is_jump' ,'advert_id_rate','advert_industry_inner_1_rate','advert_industry_inner_rate', 'advert_name_rate',
			'campaign_id_rate','creative_height_rate','creative_tp_dnf_rate','creative_width_rate' ,'province_rate', 'f_channel_rate']

media_cate_feature = ['app_cate_id', 'f_channel', 'app_id', 'inner_slot_id']



content_cate_feature = ['city', 'carrier', 'province', 'nnt', 'devtype', 'osv', 'os', 'make', 'model']

origin_cate_list = ad_cate_feature + media_cate_feature + content_cate_feature


for i in origin_cate_list:
    data[i] = data[i].map(dict(zip(data[i].unique(), range(0, data[i].nunique()))))



'''
label_feature=['adid','advert_id', 'campaign_id', 'creative_id',       
       'os', 'carrier']
'''
label_feature=[ 'city', 'province',  'carrier',
               'devtype', 'make', 'model', 'nnt', 'os', 'osv', 'adid',
               'advert_id', 'orderid', 'advert_industry_inner', 'campaign_id',
               'creative_id', 'creative_tp_dnf', 'app_cate_id', 'f_channel',
               'inner_slot_id', 'creative_type', 'creative_width', 'creative_height',
               'creative_is_jump','creative_has_deeplink','advert_name']

data['cnt']=1
col_type = label_feature.copy()
n = len(col_type)

num = 0
#df_feature = pd.DataFrame()
for i in range(n):
    col_name = "cnt_click_of_"+col_type[i]
    s = time.time()
    se = (data[col_type[i]].map(data[col_type[i]].value_counts())).astype(int)
    semax = se.max()
    semin = se.min()
    data[col_name] = ((se-se.min())/(se.max()-se.min())*100).astype(int).values
    #data[col_name]=se.astype(int).values
    num+=1
    print(num,col_name,int(time.time()-s),'s')
'''
count_feature=['cnt_click_of_adid', 'cnt_click_of_advert_id',
       'cnt_click_of_campaign_id', 'cnt_click_of_creative_id',
       'cnt_click_of_os', 'cnt_click_of_carrier']

'''
count_feature=['cnt_click_of_city',
       'cnt_click_of_province', 'cnt_click_of_carrier', 'cnt_click_of_devtype',
       'cnt_click_of_make', 'cnt_click_of_model', 'cnt_click_of_nnt',
       'cnt_click_of_os', 'cnt_click_of_osv', 'cnt_click_of_adid',
       'cnt_click_of_advert_id', 'cnt_click_of_orderid',
       'cnt_click_of_advert_industry_inner', 'cnt_click_of_campaign_id',
       'cnt_click_of_creative_id', 'cnt_click_of_creative_tp_dnf',
       'cnt_click_of_app_cate_id', 'cnt_click_of_f_channel',
       'cnt_click_of_inner_slot_id', 'cnt_click_of_creative_type',
       'cnt_click_of_creative_width', 'cnt_click_of_creative_height',
       'cnt_click_of_creative_is_jump', 'cnt_click_of_creative_has_deeplink',
       'cnt_click_of_advert_name']

cate_feature = origin_cate_list+count_feature

num_feature = ['creative_width', 'creative_height', 'hour'  , 'area', 'period', 'area_rate']

feature = cate_feature + num_feature
print(len(feature), feature)

predict = data[data.label == -1]
predict_result = predict[['instance_id']]
predict_result['predicted_score'] = 0
predict_x = predict.drop('label', axis=1)

train_x = data[data.label != -1]
train_y = data[data.label != -1].label.values






del data['click']
# 默认加载 如果 增加了cate类别特征 请改成false重新生成
if os.path.exists(path + '/feature/base_train_csr.npz') and False:
    print('load_csr---------')
    base_train_csr = sparse.load_npz(path + '/feature/base_train_csr.npz').tocsr().astype('bool')
    base_predict_csr = sparse.load_npz(path + '/feature/base_predict_csr.npz').tocsr().astype('bool')
else:
    base_train_csr = sparse.csr_matrix((len(train), 0))
    base_predict_csr = sparse.csr_matrix((len(predict_x), 0))

    enc = OneHotEncoder()
    for feature in cate_feature:
        enc.fit(data[feature].values.reshape(-1, 1))

        base_train_csr = sparse.hstack((base_train_csr, enc.transform(train_x[feature].values.reshape(-1, 1))), 'csr',
                                       'bool')
        base_predict_csr = sparse.hstack((base_predict_csr, enc.transform(predict[feature].values.reshape(-1, 1))),
                                         'csr',
                                         'bool')
    print('one-hot prepared !')

    cv = CountVectorizer(min_df=20)
    for feature in ['user_tags']:
        data[feature] = data[feature].astype(str)
        cv.fit(data[feature])
        base_train_csr = sparse.hstack((base_train_csr, cv.transform(train_x[feature].astype(str))), 'csr', 'bool')
        base_predict_csr = sparse.hstack((base_predict_csr, cv.transform(predict_x[feature].astype(str))), 'csr',
                                         'bool')
    print('cv prepared !')

    sparse.save_npz(path + '/feature/base_train_csr.npz', base_train_csr)
    sparse.save_npz(path + '/feature/base_predict_csr.npz', base_predict_csr)

train_csr = sparse.hstack(
    (sparse.csr_matrix(train_x[num_feature]), base_train_csr), 'csr').astype(
    'float32')
predict_csr = sparse.hstack(
    (sparse.csr_matrix(predict_x[num_feature]), base_predict_csr), 'csr').astype('float32')
print(train_csr.shape)
feature_select = SelectPercentile(chi2, percentile=50)
feature_select.fit(train_csr, train_y)
train_csr = feature_select.transform(train_csr)
predict_csr = feature_select.transform(predict_csr)
print('feature select')
print(train_csr.shape)


n = 1500
data_col=pd.read_csv('col_sort_best.csv',header = None)
col=data_col[0].values.copy()


lgb_model = lgb.LGBMClassifier(boosting_type='gbdt', num_leaves=62, max_depth=-1, learning_rate=0.05, n_estimators=n,
                           max_bin=425, subsample_for_bin=50000, objective='binary', min_split_gain=0,metric='binary_logloss',
                           min_child_weight=5, min_child_samples=10, subsample=0.8, subsample_freq=1,random_state=2018,
                           colsample_bytree=1, reg_alpha=3, reg_lambda=5, seed=1000, n_jobs=10, nthread=10, silent=True)

skf = StratifiedKFold(n_splits=5, random_state=2018, shuffle=True)
best_score = []
for index, (train_index, test_index) in enumerate(skf.split(train_csr, train_y)):
    print("Fold", index)
    
    i=1400
    lgb_model.fit(train_csr[train_index][:,col[:i]], train_y[train_index],
                  eval_set=[(train_csr[train_index][:,col[:i]], train_y[train_index]),
                            (train_csr[test_index][:,col[:i]], train_y[test_index])], early_stopping_rounds=100,verbose=30)
    best_score.append(lgb_model.best_score_['valid_1']['binary_logloss'])
    print(best_score)
    test_pred = lgb_model.predict_proba(predict_csr[:,col[:i]], num_iteration=lgb_model.best_iteration_)[:, 1]   
    print('test mean:', test_pred.mean())

    predict_result['predicted_score_'+str(index)] = predict_result['predicted_score'] + test_pred
print(np.mean(best_score))
predict_result['predicted_score'] = predict_result['predicted_score']/5
mean = predict_result['predicted_score'].mean()
print('mean:', mean)
now = datetime.datetime.now()
now = now.strftime('%m-%d-%H-%M')
predict_result[['instance_id', 'predicted_score']].to_csv(path + "lgb_baseline_%s.csv" % now, index=False)
# Out:
# advert_id  over
# advert_industry_inner_1  over
# advert_industry_inner  over
# advert_name  over
# campaign_id  over
# creative_height  over
# creative_tp_dnf  over
# creative_width  over
# province  over
# f_channel  over
# area  over
# 1 cnt_click_of_city 0 s
# 2 cnt_click_of_province 0 s
# 3 cnt_click_of_carrier 0 s
# 4 cnt_click_of_devtype 0 s
# 5 cnt_click_of_make 0 s
# 6 cnt_click_of_model 0 s
# 7 cnt_click_of_nnt 0 s
# 8 cnt_click_of_os 0 s
# 9 cnt_click_of_osv 0 s
# 10 cnt_click_of_adid 0 s
# 11 cnt_click_of_advert_id 0 s
# 12 cnt_click_of_orderid 0 s
# 13 cnt_click_of_advert_industry_inner 0 s
# 14 cnt_click_of_campaign_id 0 s
# 15 cnt_click_of_creative_id 0 s
# 16 cnt_click_of_creative_tp_dnf 0 s
# 17 cnt_click_of_app_cate_id 0 s
# 18 cnt_click_of_f_channel 0 s
# 19 cnt_click_of_inner_slot_id 0 s
# 20 cnt_click_of_creative_type 0 s
# 21 cnt_click_of_creative_width 0 s
# 22 cnt_click_of_creative_height 0 s
# 23 cnt_click_of_creative_is_jump 0 s
# 24 cnt_click_of_creative_has_deeplink 0 s
# 25 cnt_click_of_advert_name 0 s
# 66 ['adid', 'advert_id', 'orderid', 'advert_industry_inner_1', 'advert_industry_inner', 'advert_name', 'campaign_id', 'creative_id', 'creative_type', 'creative_tp_dnf', 'creative_has_deeplink', 'creative_is_jump', 'advert_id_rate', 'advert_industry_inner_1_rate', 'advert_industry_inner_rate', 'advert_name_rate', 'campaign_id_rate', 'creative_height_rate', 'creative_tp_dnf_rate', 'creative_width_rate', 'province_rate', 'f_channel_rate', 'app_cate_id', 'f_channel', 'app_id', 'inner_slot_id', 'city', 'carrier', 'province', 'nnt', 'devtype', 'osv', 'os', 'make', 'model', 'cnt_click_of_city', 'cnt_click_of_province', 'cnt_click_of_carrier', 'cnt_click_of_devtype', 'cnt_click_of_make', 'cnt_click_of_model', 'cnt_click_of_nnt', 'cnt_click_of_os', 'cnt_click_of_osv', 'cnt_click_of_adid', 'cnt_click_of_advert_id', 'cnt_click_of_orderid', 'cnt_click_of_advert_industry_inner', 'cnt_click_of_campaign_id', 'cnt_click_of_creative_id', 'cnt_click_of_creative_tp_dnf', 'cnt_click_of_app_cate_id', 'cnt_click_of_f_channel', 'cnt_click_of_inner_slot_id', 'cnt_click_of_creative_type', 'cnt_click_of_creative_width', 'cnt_click_of_creative_height', 'cnt_click_of_creative_is_jump', 'cnt_click_of_creative_has_deeplink', 'cnt_click_of_advert_name', 'creative_width', 'creative_height', 'hour', 'area', 'period', 'area_rate']
# one-hot prepared !
# cv prepared !
# (1001650, 27176)
# feature select
# (1001650, 13588)
# Fold 0
# Training until validation scores don't improve for 100 rounds.
# [30]	valid_0's binary_logloss: 0.428075	valid_1's binary_logloss: 0.428014
# [60]	valid_0's binary_logloss: 0.419053	valid_1's binary_logloss: 0.419377
# [90]	valid_0's binary_logloss: 0.416565	valid_1's binary_logloss: 0.417466
# [120]	valid_0's binary_logloss: 0.415199	valid_1's binary_logloss: 0.416706
# [150]	valid_0's binary_logloss: 0.414174	valid_1's binary_logloss: 0.416248
# [180]	valid_0's binary_logloss: 0.413299	valid_1's binary_logloss: 0.415905
# [210]	valid_0's binary_logloss: 0.41252	valid_1's binary_logloss: 0.415669
# [240]	valid_0's binary_logloss: 0.411816	valid_1's binary_logloss: 0.415554
# [270]	valid_0's binary_logloss: 0.411162	valid_1's binary_logloss: 0.415444
# [300]	valid_0's binary_logloss: 0.410525	valid_1's binary_logloss: 0.41534
# [330]	valid_0's binary_logloss: 0.409932	valid_1's binary_logloss: 0.415275
# [360]	valid_0's binary_logloss: 0.409377	valid_1's binary_logloss: 0.415193
# [390]	valid_0's binary_logloss: 0.408841	valid_1's binary_logloss: 0.415131
# [420]	valid_0's binary_logloss: 0.408295	valid_1's binary_logloss: 0.41511
# [450]	valid_0's binary_logloss: 0.407752	valid_1's binary_logloss: 0.415056
# [480]	valid_0's binary_logloss: 0.407234	valid_1's binary_logloss: 0.414995
# [510]	valid_0's binary_logloss: 0.406728	valid_1's binary_logloss: 0.414963
# [540]	valid_0's binary_logloss: 0.406229	valid_1's binary_logloss: 0.414942
# [570]	valid_0's binary_logloss: 0.405718	valid_1's binary_logloss: 0.414932
# [600]	valid_0's binary_logloss: 0.405241	valid_1's binary_logloss: 0.414929
# [630]	valid_0's binary_logloss: 0.404738	valid_1's binary_logloss: 0.41491
# [660]	valid_0's binary_logloss: 0.404272	valid_1's binary_logloss: 0.414936
# [690]	valid_0's binary_logloss: 0.403794	valid_1's binary_logloss: 0.414931
# [720]	valid_0's binary_logloss: 0.403322	valid_1's binary_logloss: 0.414937
# Early stopping, best iteration is:
# [632]	valid_0's binary_logloss: 0.404709	valid_1's binary_logloss: 0.414908
# [0.4149084175686846]
# test mean: 0.2130554605740598
# Fold 1
# Training until validation scores don't improve for 100 rounds.
# [30]	valid_0's binary_logloss: 0.427942	valid_1's binary_logloss: 0.428402
# [60]	valid_0's binary_logloss: 0.418997	valid_1's binary_logloss: 0.419921
# [90]	valid_0's binary_logloss: 0.416458	valid_1's binary_logloss: 0.417904
# [120]	valid_0's binary_logloss: 0.41512	valid_1's binary_logloss: 0.417152
# [150]	valid_0's binary_logloss: 0.414093	valid_1's binary_logloss: 0.416689
# [180]	valid_0's binary_logloss: 0.41323	valid_1's binary_logloss: 0.416388
# [210]	valid_0's binary_logloss: 0.412491	valid_1's binary_logloss: 0.416173
# [240]	valid_0's binary_logloss: 0.411799	valid_1's binary_logloss: 0.415999
# [270]	valid_0's binary_logloss: 0.411137	valid_1's binary_logloss: 0.415871
# [300]	valid_0's binary_logloss: 0.410534	valid_1's binary_logloss: 0.415772
# [330]	valid_0's binary_logloss: 0.409942	valid_1's binary_logloss: 0.41569
# [360]	valid_0's binary_logloss: 0.409375	valid_1's binary_logloss: 0.415627
# [390]	valid_0's binary_logloss: 0.408825	valid_1's binary_logloss: 0.415576
# [420]	valid_0's binary_logloss: 0.408286	valid_1's binary_logloss: 0.415534
# [450]	valid_0's binary_logloss: 0.40776	valid_1's binary_logloss: 0.415485
# [480]	valid_0's binary_logloss: 0.407245	valid_1's binary_logloss: 0.415438
# [510]	valid_0's binary_logloss: 0.406755	valid_1's binary_logloss: 0.415417
# [540]	valid_0's binary_logloss: 0.406262	valid_1's binary_logloss: 0.415399
# [570]	valid_0's binary_logloss: 0.405767	valid_1's binary_logloss: 0.415374
# [600]	valid_0's binary_logloss: 0.405288	valid_1's binary_logloss: 0.415347
# [630]	valid_0's binary_logloss: 0.404822	valid_1's binary_logloss: 0.415325
# [660]	valid_0's binary_logloss: 0.404349	valid_1's binary_logloss: 0.415314
# [690]	valid_0's binary_logloss: 0.40388	valid_1's binary_logloss: 0.415313
# [720]	valid_0's binary_logloss: 0.403423	valid_1's binary_logloss: 0.415296
# [750]	valid_0's binary_logloss: 0.402977	valid_1's binary_logloss: 0.415284
# [780]	valid_0's binary_logloss: 0.402542	valid_1's binary_logloss: 0.415299
# [810]	valid_0's binary_logloss: 0.402091	valid_1's binary_logloss: 0.415265
# [840]	valid_0's binary_logloss: 0.401649	valid_1's binary_logloss: 0.415286
# [870]	valid_0's binary_logloss: 0.401206	valid_1's binary_logloss: 0.415284
# [900]	valid_0's binary_logloss: 0.400751	valid_1's binary_logloss: 0.415299
# Early stopping, best iteration is:
# [813]	valid_0's binary_logloss: 0.40205	valid_1's binary_logloss: 0.415259
# [0.4149084175686846, 0.4152587266188265]
# test mean: 0.21196842042050582
# Fold 2
# Training until validation scores don't improve for 100 rounds.
# [30]	valid_0's binary_logloss: 0.428119	valid_1's binary_logloss: 0.428142
# [60]	valid_0's binary_logloss: 0.419119	valid_1's binary_logloss: 0.419383
# [90]	valid_0's binary_logloss: 0.416666	valid_1's binary_logloss: 0.417346
# [120]	valid_0's binary_logloss: 0.415275	valid_1's binary_logloss: 0.416525
# [150]	valid_0's binary_logloss: 0.414235	valid_1's binary_logloss: 0.41606
# [180]	valid_0's binary_logloss: 0.413393	valid_1's binary_logloss: 0.415766
# [210]	valid_0's binary_logloss: 0.412622	valid_1's binary_logloss: 0.415531
# [240]	valid_0's binary_logloss: 0.41192	valid_1's binary_logloss: 0.415369
# [270]	valid_0's binary_logloss: 0.41126	valid_1's binary_logloss: 0.415223
# [300]	valid_0's binary_logloss: 0.410644	valid_1's binary_logloss: 0.415128
# [330]	valid_0's binary_logloss: 0.410053	valid_1's binary_logloss: 0.415062
# [360]	valid_0's binary_logloss: 0.409487	valid_1's binary_logloss: 0.414989
# [390]	valid_0's binary_logloss: 0.408922	valid_1's binary_logloss: 0.414925
# [420]	valid_0's binary_logloss: 0.40839	valid_1's binary_logloss: 0.414872
# [450]	valid_0's binary_logloss: 0.407868	valid_1's binary_logloss: 0.414809
# [480]	valid_0's binary_logloss: 0.407346	valid_1's binary_logloss: 0.414762
# [510]	valid_0's binary_logloss: 0.406822	valid_1's binary_logloss: 0.414737
# [540]	valid_0's binary_logloss: 0.406298	valid_1's binary_logloss: 0.414707
# [570]	valid_0's binary_logloss: 0.405806	valid_1's binary_logloss: 0.414691
# [600]	valid_0's binary_logloss: 0.405315	valid_1's binary_logloss: 0.414685
# [630]	valid_0's binary_logloss: 0.404853	valid_1's binary_logloss: 0.41467
# [660]	valid_0's binary_logloss: 0.404375	valid_1's binary_logloss: 0.414671
# [690]	valid_0's binary_logloss: 0.403909	valid_1's binary_logloss: 0.414665
# [720]	valid_0's binary_logloss: 0.403458	valid_1's binary_logloss: 0.414633
# [750]	valid_0's binary_logloss: 0.402993	valid_1's binary_logloss: 0.414615
# [780]	valid_0's binary_logloss: 0.402559	valid_1's binary_logloss: 0.41462
# [810]	valid_0's binary_logloss: 0.402117	valid_1's binary_logloss: 0.414622
# [840]	valid_0's binary_logloss: 0.401668	valid_1's binary_logloss: 0.414629
# Early stopping, best iteration is:
# [752]	valid_0's binary_logloss: 0.402959	valid_1's binary_logloss: 0.414607
# [0.4149084175686846, 0.4152587266188265, 0.41460686139142655]
# test mean: 0.2119543757157591
# Fold 3
# Training until validation scores don't improve for 100 rounds.
# [30]	valid_0's binary_logloss: 0.427933	valid_1's binary_logloss: 0.428327
# [60]	valid_0's binary_logloss: 0.419046	valid_1's binary_logloss: 0.419802
# [90]	valid_0's binary_logloss: 0.416582	valid_1's binary_logloss: 0.417747
# [120]	valid_0's binary_logloss: 0.415199	valid_1's binary_logloss: 0.416856
# [150]	valid_0's binary_logloss: 0.414184	valid_1's binary_logloss: 0.416391
# [180]	valid_0's binary_logloss: 0.413308	valid_1's binary_logloss: 0.416071
# [210]	valid_0's binary_logloss: 0.412559	valid_1's binary_logloss: 0.415863
# [240]	valid_0's binary_logloss: 0.411868	valid_1's binary_logloss: 0.415663
# [270]	valid_0's binary_logloss: 0.411214	valid_1's binary_logloss: 0.415538
# [300]	valid_0's binary_logloss: 0.410608	valid_1's binary_logloss: 0.41542
# [330]	valid_0's binary_logloss: 0.410011	valid_1's binary_logloss: 0.415329
# [360]	valid_0's binary_logloss: 0.409423	valid_1's binary_logloss: 0.415251
# [390]	valid_0's binary_logloss: 0.408873	valid_1's binary_logloss: 0.415181
# [420]	valid_0's binary_logloss: 0.408325	valid_1's binary_logloss: 0.415121
# [450]	valid_0's binary_logloss: 0.407818	valid_1's binary_logloss: 0.415076
# [480]	valid_0's binary_logloss: 0.407288	valid_1's binary_logloss: 0.415056
# [510]	valid_0's binary_logloss: 0.406775	valid_1's binary_logloss: 0.415033
# [540]	valid_0's binary_logloss: 0.406279	valid_1's binary_logloss: 0.415001
# [570]	valid_0's binary_logloss: 0.40579	valid_1's binary_logloss: 0.41497
# [600]	valid_0's binary_logloss: 0.40527	valid_1's binary_logloss: 0.414961
# [630]	valid_0's binary_logloss: 0.40479	valid_1's binary_logloss: 0.414951
# [660]	valid_0's binary_logloss: 0.404314	valid_1's binary_logloss: 0.414914
# [690]	valid_0's binary_logloss: 0.403849	valid_1's binary_logloss: 0.414901
# [720]	valid_0's binary_logloss: 0.403372	valid_1's binary_logloss: 0.414876
# [750]	valid_0's binary_logloss: 0.402895	valid_1's binary_logloss: 0.414861
# [780]	valid_0's binary_logloss: 0.402431	valid_1's binary_logloss: 0.414836
# [810]	valid_0's binary_logloss: 0.401979	valid_1's binary_logloss: 0.41484
# [840]	valid_0's binary_logloss: 0.401542	valid_1's binary_logloss: 0.414842
# [870]	valid_0's binary_logloss: 0.401125	valid_1's binary_logloss: 0.414822
# [900]	valid_0's binary_logloss: 0.400693	valid_1's binary_logloss: 0.41483
# [930]	valid_0's binary_logloss: 0.400273	valid_1's binary_logloss: 0.414841
# [960]	valid_0's binary_logloss: 0.399844	valid_1's binary_logloss: 0.414822
# Early stopping, best iteration is:
# [860]	valid_0's binary_logloss: 0.401261	valid_1's binary_logloss: 0.414815
# [0.4149084175686846, 0.4152587266188265, 0.41460686139142655, 0.4148153620808163]
# test mean: 0.2125341149167372
# Fold 4
# Training until validation scores don't improve for 100 rounds.
# [30]	valid_0's binary_logloss: 0.427792	valid_1's binary_logloss: 0.428928
# [60]	valid_0's binary_logloss: 0.418735	valid_1's binary_logloss: 0.420504
# [90]	valid_0's binary_logloss: 0.41623	valid_1's binary_logloss: 0.418617
# [120]	valid_0's binary_logloss: 0.414844	valid_1's binary_logloss: 0.417856
# [150]	valid_0's binary_logloss: 0.413805	valid_1's binary_logloss: 0.4174
# [180]	valid_0's binary_logloss: 0.412938	valid_1's binary_logloss: 0.417105
# [210]	valid_0's binary_logloss: 0.412185	valid_1's binary_logloss: 0.416907
# [240]	valid_0's binary_logloss: 0.411482	valid_1's binary_logloss: 0.416775
# [270]	valid_0's binary_logloss: 0.410832	valid_1's binary_logloss: 0.416665
# [300]	valid_0's binary_logloss: 0.410193	valid_1's binary_logloss: 0.416598
# [330]	valid_0's binary_logloss: 0.409594	valid_1's binary_logloss: 0.416521
# [360]	valid_0's binary_logloss: 0.409011	valid_1's binary_logloss: 0.416493
# [390]	valid_0's binary_logloss: 0.408449	valid_1's binary_logloss: 0.416425
# [420]	valid_0's binary_logloss: 0.407922	valid_1's binary_logloss: 0.416385
# [450]	valid_0's binary_logloss: 0.407396	valid_1's binary_logloss: 0.416331
# [480]	valid_0's binary_logloss: 0.406881	valid_1's binary_logloss: 0.416321
# [510]	valid_0's binary_logloss: 0.406374	valid_1's binary_logloss: 0.41631
# [540]	valid_0's binary_logloss: 0.405869	valid_1's binary_logloss: 0.416269
# [570]	valid_0's binary_logloss: 0.405386	valid_1's binary_logloss: 0.41626
# [600]	valid_0's binary_logloss: 0.404897	valid_1's binary_logloss: 0.416246
# [630]	valid_0's binary_logloss: 0.404396	valid_1's binary_logloss: 0.41622
# [660]	valid_0's binary_logloss: 0.403913	valid_1's binary_logloss: 0.41622
# [690]	valid_0's binary_logloss: 0.403449	valid_1's binary_logloss: 0.416231
# [720]	valid_0's binary_logloss: 0.402996	valid_1's binary_logloss: 0.416204
# [750]	valid_0's binary_logloss: 0.40255	valid_1's binary_logloss: 0.416197
# [780]	valid_0's binary_logloss: 0.402097	valid_1's binary_logloss: 0.416196
# [810]	valid_0's binary_logloss: 0.401639	valid_1's binary_logloss: 0.416205
# [840]	valid_0's binary_logloss: 0.401195	valid_1's binary_logloss: 0.416219
# [870]	valid_0's binary_logloss: 0.400787	valid_1's binary_logloss: 0.416241
# Early stopping, best iteration is:
# [785]	valid_0's binary_logloss: 0.402015	valid_1's binary_logloss: 0.416191
# [0.4149084175686846, 0.4152587266188265, 0.41460686139142655, 0.4148153620808163, 0.41619112797593305]
# test mean: 0.21351500288452666
# 0.4151560991271374
# mean: 0.0
